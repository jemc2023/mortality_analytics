# %% [markdown]
# # View

# %%
# --------------------------

dbutils.secrets.listScopes()

# --------------------------
dbutils.secrets.list("semis2_scope")

# --------------------------

my_key=dbutils.secrets.get(scope="semis2_scope", key="url_tunnel")

# --------------------------

print(my_key)
